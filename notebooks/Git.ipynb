# %% [markdown]
# # Bienvenidos a mi Notebook

# %% [markdown]
# ste es un notebook de inicio para realizar análisis y visualizaciones.
#
# ## Importar Bibliotecas
# En esta celda importamos las bibliotecas necesarias.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Creación de un array de ejemplo
data = np.array([1, 2, 3, 4, 5])

# %% [markdown]
# ## Visualización de los Datos
#
# A continuación, creamos un gráfico simple para visualizar los datos.

# %%
# Gráfico simple
plt.plot(data)
plt.title('Gráfico de ejemplo')
plt.show()
